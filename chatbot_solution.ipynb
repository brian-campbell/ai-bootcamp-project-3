# %% [markdown]
# ## OSU AI Bootcamp Project 3
# ### Chatbot to recommend movies based on TMDB database search

# %%
#pip install gradio langchain tensorflow openai imdbpy google-api-python-client

import sys
# !conda install --yes --prefix {sys.prefix} gradio
# !conda install --yes --prefix {sys.prefix} langchain
# !conda install --yes --prefix {sys.prefix} langchain-community
# !conda install --yes --prefix {sys.prefix} langchain-core
# !conda install --yes --prefix {sys.prefix} tensorflow
# !conda install --yes --prefix {sys.prefix} openai
# !conda install --yes --prefix {sys.prefix} google-api-python-client
# !conda install --yes --prefix {sys.prefix} python-dotenv

# !pip install audioread
# !pip install yt_dlp
# !conda install --yes --prefix {sys.prefix} pydub
# !pip install librosa

# !pip install langchain-openai

# !pip install openai-whisper

# !pip install spacy

#!pip install websockets==13.0
# !pip uninstall -y gradio
# !pip install gradio==4.15.0
#!pip install gradio

#%pip install --upgrade --quiet  pydub
#%pip install --upgrade --quiet  librosa
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - defaults
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Channels:
#  - defaults
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3/envs/dev
#
#   added / updated specs:
#     - langchain
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     langchain-0.3.5            |     pyhd8ed1ab_0         421 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         421 KB
#
# The following packages will be UPDATED:
#
#   langchain                              0.3.4-pyhd8ed1ab_0 --> 0.3.5-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages:
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Channels:
#  - defaults
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Channels:
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Channels:
#  - defaults
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Channels:
#  - defaults
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3/envs/dev
#
#   added / updated specs:
#     - openai
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     jiter-0.6.1                |  py310hf0e4da2_0         286 KB
#     openai-1.52.1              |  py310hca03da5_0         397 KB
#     ------------------------------------------------------------
#                                            Total:         683 KB
#
# The following NEW packages will be INSTALLED:
#
#   jiter              pkgs/main/osx-arm64::jiter-0.6.1-py310hf0e4da2_0
#
# The following packages will be UPDATED:
#
#   openai                             1.37.0-py310hca03da5_0 --> 1.52.1-py310hca03da5_0
#
#
#
# Downloading and Extracting Packages:
# openai-1.52.1        | 397 KB    |                                       |   0%
# openai-1.52.1        | 397 KB    | #4                                    |   4%
# openai-1.52.1        | 397 KB    | ######################3               |  60%
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Channels:
#  - defaults
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Channels:
#  - defaults
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Requirement already satisfied: audioread in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (3.0.1)
# Requirement already satisfied: yt_dlp in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (2024.10.22)
# Requirement already satisfied: brotli in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from yt_dlp) (1.0.9)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from yt_dlp) (2024.8.30)
# Requirement already satisfied: mutagen in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from yt_dlp) (1.47.0)
# Requirement already satisfied: pycryptodomex in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from yt_dlp) (3.21.0)
# Requirement already satisfied: requests<3,>=2.32.2 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from yt_dlp) (2.32.2)
# Requirement already satisfied: urllib3<3,>=1.26.17 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from yt_dlp) (2.2.1)
# Collecting websockets>=13.0 (from yt_dlp)
#   Using cached websockets-13.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from requests<3,>=2.32.2->yt_dlp) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from requests<3,>=2.32.2->yt_dlp) (3.7)
# Using cached websockets-13.1-cp310-cp310-macosx_11_0_arm64.whl (155 kB)
# Installing collected packages: websockets
#   Attempting uninstall: websockets
#     Found existing installation: websockets 11.0.3
#     Uninstalling websockets-11.0.3:
#       Successfully uninstalled websockets-11.0.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio-client 0.8.1 requires websockets<12.0,>=10.0, but you have websockets 13.1 which is incompatible.
# Successfully installed websockets-13.1
# Channels:
#  - defaults
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Requirement already satisfied: librosa in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (0.10.2.post1)
# Requirement already satisfied: audioread>=2.1.9 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from librosa) (1.23.5)
# Requirement already satisfied: scipy>=1.2.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from librosa) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from librosa) (1.4.2)
# Requirement already satisfied: joblib>=0.14 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from librosa) (0.59.1)
# Requirement already satisfied: soundfile>=0.12.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from librosa) (4.11.0)
# Requirement already satisfied: lazy-loader>=0.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from librosa) (1.0.3)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from lazy-loader>=0.1->librosa) (23.2)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from numba>=0.51.0->librosa) (0.42.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from pooch>=1.1->librosa) (3.10.0)
# Requirement already satisfied: requests>=2.19.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from pooch>=1.1->librosa) (2.32.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2024.8.30)
# Requirement already satisfied: langchain-openai in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (0.2.3)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.12 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from langchain-openai) (0.3.13)
# Requirement already satisfied: openai<2.0.0,>=1.52.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from langchain-openai) (1.52.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from langchain-openai) (0.8.0)
# Requirement already satisfied: PyYAML>=5.3 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.12->langchain-openai) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.12->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.12->langchain-openai) (0.1.129)
# Requirement already satisfied: packaging<25,>=23.2 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.12->langchain-openai) (23.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.12->langchain-openai) (2.8.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.12->langchain-openai) (8.2.2)
# Requirement already satisfied: typing-extensions>=4.7 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.12->langchain-openai) (4.11.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from openai<2.0.0,>=1.52.0->langchain-openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from openai<2.0.0,>=1.52.0->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from openai<2.0.0,>=1.52.0->langchain-openai) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from openai<2.0.0,>=1.52.0->langchain-openai) (0.6.1)
# Requirement already satisfied: sniffio in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from openai<2.0.0,>=1.52.0->langchain-openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from openai<2.0.0,>=1.52.0->langchain-openai) (4.66.4)
# Requirement already satisfied: regex>=2022.1.18 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2023.10.3)
# Requirement already satisfied: requests>=2.26.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.32.2)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.52.0->langchain-openai) (3.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.52.0->langchain-openai) (1.2.0)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.52.0->langchain-openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.52.0->langchain-openai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.52.0->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.12->langchain-openai) (2.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.12->langchain-openai) (3.10.7)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.12->langchain-openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.12->langchain-openai) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.2.1)
# Requirement already satisfied: openai-whisper in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (20240930)
# Requirement already satisfied: numba in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from openai-whisper) (0.59.1)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from openai-whisper) (1.23.5)
# Requirement already satisfied: torch in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from openai-whisper) (2.5.0)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from openai-whisper) (4.66.4)
# Requirement already satisfied: more-itertools in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from openai-whisper) (10.1.0)
# Requirement already satisfied: tiktoken in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from openai-whisper) (0.8.0)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from numba->openai-whisper) (0.42.0)
# Requirement already satisfied: regex>=2022.1.18 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from tiktoken->openai-whisper) (2023.10.3)
# Requirement already satisfied: requests>=2.26.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from tiktoken->openai-whisper) (2.32.2)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from torch->openai-whisper) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from torch->openai-whisper) (4.11.0)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from torch->openai-whisper) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from torch->openai-whisper) (3.1.4)
# Requirement already satisfied: fsspec in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from torch->openai-whisper) (2024.3.1)
# Requirement already satisfied: sympy==1.13.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from torch->openai-whisper) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from sympy==1.13.1->torch->openai-whisper) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken->openai-whisper) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from jinja2->torch->openai-whisper) (2.1.3)
# Requirement already satisfied: spacy in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy) (1.0.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy) (3.0.6)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy) (8.2.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy) (0.9.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy) (2.32.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy) (2.8.2)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy) (69.5.1)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy) (1.23.5)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from jinja2->spacy) (2.1.3)
# Found existing installation: gradio 4.15.0
# Uninstalling gradio-4.15.0:
#   Successfully uninstalled gradio-4.15.0
# Collecting gradio==4.15.0
#   Using cached gradio-4.15.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from gradio==4.15.0) (22.1.0)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from gradio==4.15.0) (5.0.1)
# Requirement already satisfied: fastapi in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from gradio==4.15.0) (0.112.2)
# Requirement already satisfied: ffmpy in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from gradio==4.15.0) (0.3.0)
# Requirement already satisfied: gradio-client==0.8.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from gradio==4.15.0) (0.8.1)
# Requirement already satisfied: httpx in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from gradio==4.15.0) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from gradio==4.15.0) (0.25.1)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from gradio==4.15.0) (6.1.1)
# Requirement already satisfied: jinja2<4.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from gradio==4.15.0) (3.1.4)
# Requirement already satisfied: markupsafe~=2.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from gradio==4.15.0) (2.1.3)
# Requirement already satisfied: matplotlib~=3.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from gradio==4.15.0) (3.8.4)
# Requirement already satisfied: numpy~=1.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from gradio==4.15.0) (1.23.5)
# Requirement already satisfied: orjson~=3.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from gradio==4.15.0) (3.10.7)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from gradio==4.15.0) (23.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from gradio==4.15.0) (2.2.2)
# Requirement already satisfied: pillow<11.0,>=8.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from gradio==4.15.0) (10.3.0)
# Requirement already satisfied: pydantic>=2.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from gradio==4.15.0) (2.8.2)
# Requirement already satisfied: pydub in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from gradio==4.15.0) (0.25.1)
# Requirement already satisfied: python-multipart in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from gradio==4.15.0) (0.0.12)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from gradio==4.15.0) (6.0.1)
# Requirement already satisfied: ruff>=0.1.7 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from gradio==4.15.0) (0.3.5)
# Requirement already satisfied: semantic-version~=2.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from gradio==4.15.0) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from gradio==4.15.0) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.9 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9->gradio==4.15.0) (0.9.4)
# Requirement already satisfied: typing-extensions~=4.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from gradio==4.15.0) (4.11.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from gradio==4.15.0) (0.20.0)
# Requirement already satisfied: fsspec in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from gradio-client==0.8.1->gradio==4.15.0) (2024.3.1)
# Collecting websockets<12.0,>=10.0 (from gradio-client==0.8.1->gradio==4.15.0)
#   Using cached websockets-11.0.3-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: jsonschema>=3.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from altair<6.0,>=4.2.0->gradio==4.15.0) (4.23.0)
# Requirement already satisfied: toolz in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from altair<6.0,>=4.2.0->gradio==4.15.0) (0.12.0)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from huggingface-hub>=0.19.3->gradio==4.15.0) (3.13.1)
# Requirement already satisfied: requests in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from huggingface-hub>=0.19.3->gradio==4.15.0) (2.32.2)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from huggingface-hub>=0.19.3->gradio==4.15.0) (4.66.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from matplotlib~=3.0->gradio==4.15.0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from matplotlib~=3.0->gradio==4.15.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from matplotlib~=3.0->gradio==4.15.0) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from matplotlib~=3.0->gradio==4.15.0) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from matplotlib~=3.0->gradio==4.15.0) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from matplotlib~=3.0->gradio==4.15.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from pandas<3.0,>=1.0->gradio==4.15.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from pandas<3.0,>=1.0->gradio==4.15.0) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from pydantic>=2.0->gradio==4.15.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from pydantic>=2.0->gradio==4.15.0) (2.20.1)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from typer<1.0,>=0.9->typer[all]<1.0,>=0.9->gradio==4.15.0) (8.1.7)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9->gradio==4.15.0) (0.4.6)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9->gradio==4.15.0) (1.5.0)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9->gradio==4.15.0) (13.3.5)
# Requirement already satisfied: h11>=0.8 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from uvicorn>=0.14.0->gradio==4.15.0) (0.14.0)
# Requirement already satisfied: starlette<0.39.0,>=0.37.2 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from fastapi->gradio==4.15.0) (0.38.2)
# Requirement already satisfied: anyio in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from httpx->gradio==4.15.0) (4.2.0)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from httpx->gradio==4.15.0) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from httpx->gradio==4.15.0) (1.0.2)
# Requirement already satisfied: idna in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from httpx->gradio==4.15.0) (3.7)
# Requirement already satisfied: sniffio in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from httpx->gradio==4.15.0) (1.3.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.15.0) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.15.0) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.15.0) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.15.0) (0.10.6)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio==4.15.0) (1.16.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio==4.15.0) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio==4.15.0) (2.15.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from anyio->httpx->gradio==4.15.0) (1.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from requests->huggingface-hub>=0.19.3->gradio==4.15.0) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from requests->huggingface-hub>=0.19.3->gradio==4.15.0) (2.2.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio==4.15.0) (0.1.0)
# Using cached gradio-4.15.0-py3-none-any.whl (16.6 MB)
# Using cached websockets-11.0.3-cp310-cp310-macosx_11_0_arm64.whl (121 kB)
# Installing collected packages: websockets, gradio
#   Attempting uninstall: websockets
#     Found existing installation: websockets 13.1
#     Uninstalling websockets-13.1:
#       Successfully uninstalled websockets-13.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yt-dlp 2024.10.22 requires websockets>=13.0, but you have websockets 11.0.3 which is incompatible.
# Successfully installed gradio-4.15.0 websockets-11.0.3

# %% [markdown]
# ### Project imports for libraries, functions, and classes

# %%
# AI/ML specific imports
import gradio as gr
from langchain.prompts import ChatPromptTemplate
from langchain.chains import LLMChain
from langchain.llms import OpenAI
import imdb  # IMDBPY library for querying IMDB
from imdb import Cinemagoer 
import requests
from googleapiclient.discovery import build
from langchain.chat_models import ChatOpenAI
import spacy
import requests
from langchain import ConversationChain
from langchain.prompts import PromptTemplate


# OS/ENV specific imports
from dotenv import load_dotenv
import os

# %% [markdown]
# ### Load the environment

# %%
load_dotenv ( override=True )
# Out:
# True

# %% [markdown]
# ### Read API keys from config file

# %%
openai_api_key = os.getenv ( "OPENAI_API_KEY" )
google_api_key = os.getenv ( "GOOGLE_API_KEY" )
search_engine_id = os.getenv ( "SEARCH_ENGINE_ID" )
tmdb_api_key = os.getenv ( "TMDB_API_KEY" )

print ( openai_api_key, google_api_key, search_engine_id, tmdb_api_key )

print ( os.environ )
# Out:
# sk-zgqeqO5p61SnqexHgSO6b-ndwqaYRxrOLd9wKNINYqT3BlbkFJmkXCRBhwgED6JEWyCQMq0xa-CjJaGeIfOPOeGS2CIA AIzaSyCqHxaQrT9Y0nUeF_KAohdDXPUyxO0qUIs AIzaSyCqHxaQrT9Y0nUeF_KAohdDXPUyxO0qUIs f5290af46b2e149a06a590898158dc9e
# environ({'AR': 'arm64-apple-darwin20.0.0-ar', 'AS': 'arm64-apple-darwin20.0.0-as', 'BUILD': 'arm64-apple-darwin20.0.0', 'CC': 'arm64-apple-darwin20.0.0-clang', 'CC_FOR_BUILD': '/opt/anaconda3/envs/dev/bin/arm64-apple-darwin20.0.0-clang', 'CFLAGS': '-ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -isystem /opt/anaconda3/envs/dev/include', 'CHECKSYMS': 'arm64-apple-darwin20.0.0-checksyms', 'CLANG': 'arm64-apple-darwin20.0.0-clang', 'CLANGXX': 'arm64-apple-darwin20.0.0-clang++', 'CMAKE_ARGS': '-DCMAKE_AR=/opt/anaconda3/envs/dev/bin/arm64-apple-darwin20.0.0-ar -DCMAKE_CXX_COMPILER_AR=/opt/anaconda3/envs/dev/bin/arm64-apple-darwin20.0.0-ar -DCMAKE_C_COMPILER_AR=/opt/anaconda3/envs/dev/bin/arm64-apple-darwin20.0.0-ar -DCMAKE_RANLIB=/opt/anaconda3/envs/dev/bin/arm64-apple-darwin20.0.0-ranlib -DCMAKE_CXX_COMPILER_RANLIB=/opt/anaconda3/envs/dev/bin/arm64-apple-darwin20.0.0-ranlib -DCMAKE_C_COMPILER_RANLIB=/opt/anaconda3/envs/dev/bin/arm64-apple-darwin20.0.0-ranlib -DCMAKE_LINKER=/opt/anaconda3/envs/dev/bin/arm64-apple-darwin20.0.0-ld -DCMAKE_STRIP=/opt/anaconda3/envs/dev/bin/arm64-apple-darwin20.0.0-strip -DCMAKE_INSTALL_NAME_TOOL=/opt/anaconda3/envs/dev/bin/arm64-apple-darwin20.0.0-install_name_tool -DCMAKE_LIBTOOL=/opt/anaconda3/envs/dev/bin/arm64-apple-darwin20.0.0-libtool -DCMAKE_OSX_DEPLOYMENT_TARGET= -DCMAKE_BUILD_TYPE=Release -DCMAKE_OSX_SYSROOT=/Applications/Xcode.app/Contents/Developer/Platforms/MacOSX.platform/Developer/SDKs/MacOSX.sdk', 'CMAKE_PREFIX_PATH': ':/opt/anaconda3/envs/dev', 'CMDSTAN': '/opt/anaconda3/envs/dev/bin/cmdstan', 'COLORFGBG': '15;0', 'COLORTERM': 'truecolor', 'COMMAND_MODE': 'unix2003', 'CONDA_BACKUP_HOST': 'ðV¡jU', 'CONDA_DEFAULT_ENV': 'dev', 'CONDA_EXE': '/opt/anaconda3/bin/conda', 'CONDA_PREFIX': '/opt/anaconda3/envs/dev', 'CONDA_PREFIX_1': '/opt/anaconda3', 'CONDA_PROMPT_MODIFIER': '(dev) ', 'CONDA_PYTHON_EXE': '/opt/anaconda3/bin/python', 'CONDA_SHLVL': '4', 'CONDA_TOOLCHAIN_BUILD': 'arm64-apple-darwin20.0.0', 'CONDA_TOOLCHAIN_HOST': 'arm64-apple-darwin20.0.0', 'CPPFLAGS': '-D_FORTIFY_SOURCE=2 -isystem /opt/anaconda3/envs/dev/include', 'CUP_DIR': '/Users/briancampbell/cup', 'CXX': 'arm64-apple-darwin20.0.0-clang++', 'CXXFLAGS': '-ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden -fmessage-length=0 -isystem /opt/anaconda3/envs/dev/include', 'CXX_FOR_BUILD': '/opt/anaconda3/envs/dev/bin/arm64-apple-darwin20.0.0-clang++', 'DEBUG_CFLAGS': '-ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -Og -g -Wall -Wextra -isystem /opt/anaconda3/envs/dev/include', 'DEBUG_CXXFLAGS': '-ftree-vectorize -fPIC -fPIE -fstack-protector-strong -O2 -pipe -stdlib=libc++ -fvisibility-inlines-hidden -fmessage-length=0 -Og -g -Wall -Wextra -isystem /opt/anaconda3/envs/dev/include', 'ELECTRON_NO_ATTACH_CONSOLE': '1', 'GSETTINGS_SCHEMA_DIR': '/opt/anaconda3/envs/dev/share/glib-2.0/schemas', 'HOME': '/Users/briancampbell', 'HOST': 'arm64-apple-darwin20.0.0', 'INSTALL_NAME_TOOL': 'arm64-apple-darwin20.0.0-install_name_tool', 'ITERM_PROFILE': 'Default', 'ITERM_SESSION_ID': 'w1t0p0:3AEFD0E7-93AC-4755-BC04-6B250648837D', 'JFLEX_DIR': '/Users/briancampbell/jflex-1.7.0', 'LANG': 'en_US.UTF-8', 'LC_TERMINAL': 'iTerm2', 'LC_TERMINAL_VERSION': '3.5.5', 'LD': 'arm64-apple-darwin20.0.0-ld', 'LDFLAGS': '-Wl,-pie -Wl,-headerpad_max_install_names -Wl,-dead_strip_dylibs -Wl,-rpath,/opt/anaconda3/envs/dev/lib -L/opt/anaconda3/envs/dev/lib', 'LDFLAGS_LD': '-pie -headerpad_max_install_names -dead_strip_dylibs -rpath /opt/anaconda3/envs/dev/lib -L/opt/anaconda3/envs/dev/lib', 'LESS': '-R', 'LIBTOOL': 'arm64-apple-darwin20.0.0-libtool', 'LIPO': 'arm64-apple-darwin20.0.0-lipo', 'LOGNAME': 'briancampbell', 'LSCOLORS': 'Gxfxcxdxbxegedabagacad', 'LS_COLORS': 'rs=0:di=01;34:ln=01;36:mh=00:pi=40;33:so=01;35:do=01;35:bd=40;33;01:cd=40;33;01:or=40;31;01:mi=00:su=37;41:sg=30;43:ca=00:tw=30;42:ow=34;42:st=37;44:ex=01;32:*.7z=01;31:*.ace=01;31:*.alz=01;31:*.apk=01;31:*.arc=01;3 ...

# %% [markdown]
# ##################################################################################
# ### Direct use of ChatGPT - no real processing done on client side
# ##################################################################################

# %%
# LangChain setup
#llm = ChatOpenAI(model_name='gpt-4')
chatgpt_llm = ChatOpenAI ( model_name='gpt-3.5-turbo' )


# Chatbot prompt
chatgpt_prompt_template = ChatPromptTemplate.from_template (
    "You are a movie recommendation bot. The user will provide a list of criteria (genre, rating, year, etc.) "
    "and your task is to find the best matching movies. If nothing is found, try searching on Google. "
    "The user query is: {user_query}"
)

chatgpt_chain = LLMChain ( llm=chatgpt_llm, prompt=chatgpt_prompt_template )
# Out:
# /var/folders/7r/q8fxy3mj2hx4lvdrd4d1dfbh0000gn/T/ipykernel_19026/409308859.py:3: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   chatgpt_llm = ChatOpenAI ( model_name='gpt-3.5-turbo' )
# /var/folders/7r/q8fxy3mj2hx4lvdrd4d1dfbh0000gn/T/ipykernel_19026/409308859.py:13: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   chatgpt_chain = LLMChain ( llm=chatgpt_llm, prompt=chatgpt_prompt_template )

# %%
def chatgpt_direct_movie_recommender ( user_query ):
    chatgpt_chain_response = chatgpt_chain.run ( {"user_query": user_query} )
    print ( chatgpt_chain_response )
    return chatgpt_chain_response

# Create a Gradio interface
chatgpt_interface = gr.Interface ( fn=chatgpt_direct_movie_recommender,
    inputs=gr.Textbox ( label="Recommendation text", lines=4, placeholder="Ask for movie recommendations..." ),
    outputs=gr.Textbox ( label="Recommendation from ChatGPT", lines=4 ),
    title="ChatGPT Direct Movie Recommender Bot",
    description="OpenAI ChatGPT Interface" )

# Launch the app
chatgpt_interface.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# IMPORTANT: You are using gradio version 4.15.0, however version 4.44.1 is available, please upgrade.
# --------

# %% [markdown]
# ### Chatbot that interacts with ChatGPT in a different way.
# ### This chatbot uses ConversationChain along with ChatOpenAI

# %%
from langchain import ConversationChain
from langchain.chat_models import ChatOpenAI
from langchain.memory import ConversationBufferMemory
from langchain.prompts import PromptTemplate
import requests
import os
import gradio as gr

# Set OpenAI and TMDb API keys
openai_api_key = "sk-svcacct-gCfZzvxqywYyhlW707rzn55aw_uE8OZgn-OJoWoZw0pii-LdD6dJN5gp4fBncT3BlbkFJBvpw97Xu267gUY7oWxNesfVzeTl2xjl9Hxj71UUf_Y7Y6fE_RMZ6v576KK67AA"  
tmdb_api_key = "7606a082a3cb4ebef8db46609a0994e0"  

# Define a function to query the TMDb API for movie recommendations
def query_tmdb(genre=None, min_year=None, max_year=None, min_rating=None, max_rating=None, max_runtime=None):
    base_url = "https://api.themoviedb.org/3/discover/movie"
    params = {
        "api_key": tmdb_api_key,
        "language": "en-US",
        "sort_by": "popularity.desc",
        "include_adult": "false",
        "with_genres": genre,
        "primary_release_date.gte": f"{min_year}-01-01" if min_year else None,
        "primary_release_date.lte": f"{max_year}-12-31" if max_year else None,
        "vote_average.gte": min_rating,
        "vote_average.lte": max_rating,
        "with_runtime.lte": max_runtime,
        "page": 1
    }
    # Filter out None values in params
    params = {k: v for k, v in params.items() if v is not None}
    response = requests.get(base_url, params=params)
    
    if response.status_code == 200:
        movies = response.json().get("results", [])
        movie_details = []
        for movie in movies[:10]:  # Limit to top 10 results for performance
            # Get additional details, including runtime, by movie ID
            movie_id = movie['id']
            detail_response = requests.get(f"https://api.themoviedb.org/3/movie/{movie_id}", params={"api_key": tmdb_api_key})
            if detail_response.status_code == 200:
                details = detail_response.json()
                movie_details.append(
                    f"{movie['title']} ({movie['release_date'][:4]}), Rating: {movie.get('vote_average', 'N/A')}, "
                    f"Runtime: {details.get('runtime', 'N/A')} minutes"
                )
            else:
                movie_details.append(f"{movie['title']} - Additional details unavailable.")
        return movie_details
    else:
        return ["No results found."]

# %%
# Set up LangChain with prompt and memory
prompt_template = PromptTemplate(
    input_variables=["input", "history"],
    template="""You are a helpful assistant for movie recommendations. When users ask for movies, ask for genre, year, rating, or runtime if needed and then provide recommendations based on TMDb API.

    Conversation History:
    {history}

    User: {input}
    Assistant:"""
)
memory = ConversationBufferMemory(return_messages=True)
llm = ChatOpenAI(temperature=0, openai_api_key=openai_api_key)
chatgpt_chain = ConversationChain(llm=llm, memory=memory, prompt=prompt_template)
# Out:
# /var/folders/7r/q8fxy3mj2hx4lvdrd4d1dfbh0000gn/T/ipykernel_19026/3033465025.py:12: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationBufferMemory(return_messages=True)
# /var/folders/7r/q8fxy3mj2hx4lvdrd4d1dfbh0000gn/T/ipykernel_19026/3033465025.py:14: LangChainDeprecationWarning: The class `ConversationChain` was deprecated in LangChain 0.2.7 and will be removed in 1.0. Use :meth:`~RunnableWithMessageHistory: https://python.langchain.com/v0.2/api_reference/core/runnables/langchain_core.runnables.history.RunnableWithMessageHistory.html` instead.
#   chatgpt_chain = ConversationChain(llm=llm, memory=memory, prompt=prompt_template)

# %%
# Function to handle user queries and call the TMDb API based on input details
def chatgpt_direct_movie_recommender(user_query):
    # Get response from LangChain conversation chain
    chat_response = chatgpt_chain.predict(input=user_query)
    print ( chat_response )
    
    return chat_response

# Set up Gradio interface for interactive use
chatgpt_interface = gr.Interface(
    fn=chatgpt_direct_movie_recommender,
    inputs="text",
    outputs="text",
    title="Movie Recommender Bot"
)

# Launch the Gradio app
chatgpt_interface.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7864
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7864/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# IMPORTANT: You are using gradio version 4.15.0, however version 4.44.1 is available, please upgrade.
# --------
# Sure! Could you please specify if you have any preference for the year within that range, or should I provide recommendations for all years between 2000 and 2020?
# Sure! Here are some movie recommendations for you:
#
# 1. "The Dark Knight" (2008) - A thrilling action-packed movie with a rating of 9.0 on TMDb.
# 2. "Inception" (2010) - A mind-bending action movie with a rating of 8.8 on TMDb.
# 3. "The Shawshank Redemption" (1994) - A classic drama film with a rating of 8.7 on TMDb.
# 4. "The Lord of the Rings: The Return of the King" (2003) - An epic fantasy movie with a rating of 8.7 on TMDb.
# 5. "Interstellar" (2014) - A sci-fi adventure film with a rating of 8.6 on TMDb.
#
# Enjoy watching these movies!

# %% [markdown]
# ### Helper function code to query TMDB

# %%
def query_tmdb(genre=None, min_year=None, max_year=None, min_rating=None, min_runtime=None, max_runtime=None, search_term=None):
    """
    Query TMDb for movies based on genre, year, rating, and runtime.
    :param genre: Filter by genre (e.g., 'comedy', 'action').
    :param min_year: Minimum year for movie release.
    :param max_year: Maximum year for movie release.
    :param min_rating: Minimum TMDb rating (e.g., 7.0).
    :param max_runtime: Maximum movie runtime in minutes.
    :param search_term: Optional search term for a specific movie or keyword.
    :return: List of filtered movie results.
    """
    # The base URL for querying TMDb
    base_url = 'https://api.themoviedb.org/3/discover/movie'

    # TMDb requires genre IDs, so let's map some popular genres to their respective TMDb genre IDs
#    genre_map = {
#        'action': 28,
#        'comedy': 35,
#        'drama': 18,
#        'horror': 27,
#        'romance': 10749,
#        'sci-fi': 878
#    }

    # Formate release dates
    if min_year != None:
        min_year = f"{min_year}-01-01"
    if max_year != None:
        max_year = f"{max_year}-12-31"

    # Build the query parameters
    params = {
        'api_key': tmdb_api_key,
        'language': 'en-US',
        'sort_by': 'popularity.desc',
        'include_adult': 'false',
        'include_video': 'false',
#        'with_genres': genre_map.get(genre.lower()) if genre else None,
        'with_genres': genre if genre else None,
        'primary_release_date.gte': min_year if min_year else None,
        'primary_release_date.lte': max_year if max_year else None,
        'vote_average.gte': min_rating if min_rating else None,
        'with_runtime.lte': max_runtime if max_runtime else None,
        'with_runtime.gte': min_runtime if min_runtime else None,
        'query': search_term if search_term else None,
        'page': 1
    }

    # Remove any parameters that are None
    params = {k: v for k, v in params.items() if v is not None}
    print (params)

    # Send the GET request to TMDb API
    response = requests.get(base_url, params=params)

    # Check for successful response
    if response.status_code == 200:
        data = response.json()
        results = data.get('results', [])
        print (results)

    for movie in results[:5]:  # Limit to top 5 results
    #    print (movie)
        detail_url = "https://api.themoviedb.org/3/movie/" + str(movie['id']) + "?api_key=" + tmdb_api_key
    #    print (detail_url)
        
        response = requests.get ( detail_url )

        # Check for successful response
        if response.status_code == 200:
            results = response.json ()
    #        print (results)
        
        recommendation = "Check out: " + movie['title'] + " released in: " + movie['release_date'][:4] + " with an average rating of: " + str ( movie.get('vote_average', 'N/A') ) + " and a runtime of: " + str ( results.get('runtime', 'N/A') ) + " min"
        print(f"{movie['title']} ({movie['release_date'][:4]}) - Rating: {movie.get('vote_average', 'N/A')}, Runtime: {results.get('runtime', 'N/A')} min")        
        
        return recommendation
    else:
        print(f"Error: {response.status_code}")
        return []

# %% [markdown]
# ##################################################################################
# ### Code to query YouTube for audio files that request movie recommendations
# ##################################################################################

# %%
from langchain_community.document_loaders.blob_loaders.youtube_audio import ( YoutubeAudioLoader, )
from langchain_community.document_loaders.generic import GenericLoader
#from langchain_community.document_loaders.parsers import ( OpenAIWhisperParser, OpenAIWhisperParserLocal, )
from langchain_community.document_loaders.parsers import ( OpenAIWhisperParser, )

# !python3 -m spacy download en_core_web_sm
# !python3 -m spacy download en_core_web_lg
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 11.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from en-core-web-sm==3.7.1) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.6)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.8.2)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (69.5.1)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.23.5)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.3)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# Collecting en-core-web-lg==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.7.1/en_core_web_lg-3.7.1-py3-none-any.whl (587.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 4.1 MB/s eta 0:00:00m eta 0:00:010:00:02
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from en-core-web-lg==3.7.1) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.0.7)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.0.6)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.2.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.9.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.32.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.8.2)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (69.5.1)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (1.23.5)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/dev/lib/python3.10/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-lg==3.7.1) (2.1.3)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %% [markdown]
# ### Helper function to turn basic time text/value to something usable by TMDB

# %%
import re

def parse_time_to_minutes ( time_phrase ):
    # Patterns for different time expressions
    less_than_pattern = re.compile(r'less than (\d+)\s*(hours?|mins?|minutes?)', re.IGNORECASE)
    more_than_pattern = re.compile(r'more than (\d+)\s*(hours?|mins?|minutes?)', re.IGNORECASE)
    between_pattern = re.compile(r'between (\d+)\s*(hours?|mins?|minutes?) and (\d+)\s*(hours?|mins?|minutes?)', re.IGNORECASE)
    exact_pattern = re.compile(r'(\d+)\s*(hours?|mins?|minutes?)', re.IGNORECASE)

    # Helper function to convert hours or minutes to minutes
    def convert_to_minutes(amount, unit):
        return amount * 60 if "hour" in unit.lower() else amount

    # "less than X hours/minutes" pattern
    if less_than := less_than_pattern.search(time_phrase):
        max_minutes = convert_to_minutes(int(less_than.group(1)), less_than.group(2))
        return 0, max_minutes

    # "more than X hours/minutes" pattern
    elif more_than := more_than_pattern.search(time_phrase):
        min_minutes = convert_to_minutes(int(more_than.group(1)), more_than.group(2))
        return min_minutes, None

    # "between X and Y hours/minutes" pattern
    elif between := between_pattern.search(time_phrase):
        min_minutes = convert_to_minutes(int(between.group(1)), between.group(2))
        max_minutes = convert_to_minutes(int(between.group(3)), between.group(4))
        return min_minutes, max_minutes

    # "X hours/minutes" pattern (exact amount)
    elif exact := exact_pattern.search(time_phrase):
        minutes = convert_to_minutes(int(exact.group(1)), exact.group(2))
        return minutes, minutes

    # If no pattern matched, return None
    return None

# %% [markdown]
# ### Use spaCy/NLP to process user request

# %%
import re
from spacy.tokenizer import Tokenizer
from spacy.util import compile_infix_regex

# Predefined genres and their TMDB IDs
GENRE_MAP = {
    "action": 28,
    "comedy": 35,
    "drama": 18,
    "horror": 27,
    "sci-fi": 878,
    "thriller": 53,
    "romance": 10749
}

def parse_youtube_text_and_search ( youtube_text ):
    nlp = spacy.load ( "en_core_web_lg" )
    
    ###########################################################################
    def custom_tokenizer(nlp):
        inf = list(nlp.Defaults.infixes)               # Default infixes
        inf.remove(r"(?<=[0-9])[+\-\*^](?=[0-9-])")    # Remove the generic op between numbers or between a number and a -
        inf = tuple(inf)                               # Convert inf to tuple
        infixes = inf + tuple([r"(?<=[0-9])[+*^](?=[0-9-])", r"(?<=[0-9])-(?=-)"])  # Add the removed rule after subtracting (?<=[0-9])-(?=[0-9]) pattern
        infixes = [x for x in infixes if '-|–|—|--|---|——|~' not in x] # Remove - between letters rule
        infix_re = compile_infix_regex(infixes)

        return Tokenizer (nlp.vocab, prefix_search=nlp.tokenizer.prefix_search,
                                    suffix_search=nlp.tokenizer.suffix_search,
                                    infix_finditer=infix_re.finditer,
                                    token_match=nlp.tokenizer.token_match,
                                    rules=nlp.Defaults.tokenizer_exceptions )

    nlp.tokenizer = custom_tokenizer(nlp)    
    
    ###########################################################################
    
    parsed_doc = None
    parsed_doc = nlp ( youtube_text )
    
    print ( f"pd: {parsed_doc}" )
    print ( parsed_doc.ents )
    
    genre = None
    start_year = None
    end_year = None
    min_rating = None
    min_runtime = None
    max_runtime = None
    
    ###########################################################################
    # Detect genre
    for token in parsed_doc:
        if token.text.lower () in GENRE_MAP:
            genre = GENRE_MAP[token.text.lower ()]
            break
        
    ###########################################################################
    # Detect years and ranges
    for ent in parsed_doc.ents:
        if ent.label_ == "DATE":
            # Extract full four-digit years from the DATE entity text
            years = re.findall(r"\b(19|20)\d{2}\b", ent.text)
            # Convert matched years to integers and ensure they capture correctly
            years = [int("".join(year)) for year in re.findall(r"(19\d{2}|20\d{2})", ent.text)]
            if len(years) == 2:
                start_year, end_year = years[0], years[1]
            elif len(years) == 1:
                start_year = years[0]


    ###########################################################################
    # Detect runtime requests
    for ent in parsed_doc.ents:
        if ent.label_ == "TIME":
            min_runtime, max_runtime = parse_time_to_minutes ( ent.text )

    ###########################################################################
    # Detect minimum rating
    rating_match = re.search(r"(\d+\.\d+)", youtube_text)
    if rating_match:
        min_rating = float(rating_match.group(1))


    for ent in parsed_doc.ents:
        print ( f"ent label: {ent.label_}" )

    for token in parsed_doc:
        print ( f"token: {token}" )

    print ( f"Genre: {genre}, Start Year: {start_year}, End Year: {end_year}, Min Rating: {min_rating}, Min Runtime: {min_runtime}, Max Runtime: {max_runtime}"  )
        
    recommended_movie = query_tmdb ( genre, start_year, end_year, min_rating, min_runtime, max_runtime )
    
    return recommended_movie

# %% [markdown]
# ### Code to retrieve YouTube video and transcribe audio to text for processing
# ### via the spacy/NLP library

# %%
# set a flag to switch between local and remote parsing
# change this to True if you want to use local parsing
local = False

def transcribe_youtube ( url ):
    if type ( url ) is not list:
        tmp = []
        tmp.append ( url )
        url = tmp
        
    # Directory to save audio files
    save_dir = "."
    
    # Transcribe the videos to text
#    if local:
#        loader = GenericLoader (
#            YoutubeAudioLoader ( url, save_dir ), OpenAIWhisperParserLocal ()
#        )
#    else:
    yl = YoutubeAudioLoader ( url, save_dir )
    loader = GenericLoader ( yl, OpenAIWhisperParser () )

    
    doc = None
    doc = loader.load ()

#    yl.
    
    d = doc[0]
    
    for filename in os.listdir ( save_dir ):
        if filename.endswith ( '.m4a' ):
            file_path = os.path.join ( save_dir, filename )
            try:
                os.remove ( file_path )
                print ( f"Deleted: {file_path}" )
            except OSError as e:
                print ( f"Error deleting {file_path}: {e}" )
                
    value = parse_youtube_text_and_search ( d.page_content )
    
    return value

# %% [markdown]
# ### Gradio app for chatbot interface.
# ### Test URLs:
# * https://youtube.com/shorts/iYCutqWHVrI
# * https://youtube.com/shorts/plAZ21dkhaE
# * https://youtube.com/shorts/UQ6vLRY2B8o

# %%
# Gradio Interface for LangChain-based Chatbot
youtube_interface = gr.Interface (
    fn=transcribe_youtube,
    inputs=gr.Textbox ( label="YouTube URL", lines=4, placeholder="Ask for movie recommendations..." ),
    outputs=gr.Textbox ( label="Recommendation", lines=4 ),
    title="YouTube Translater for Movie Recommendation Chatbot",
    description="Input URL for YouTube video to translate to a movie recommendation!"
)

# Start the interface
youtube_interface.launch ()
# Out:
# Running on local URL:  http://127.0.0.1:7862
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# IMPORTANT: You are using gradio version 4.15.0, however version 4.44.1 is available, please upgrade.
# --------
# [youtube] Extracting URL: https://www.youtube.com/shorts/iYCutqWHVrI
# [youtube] iYCutqWHVrI: Downloading webpage
# [youtube] iYCutqWHVrI: Downloading ios player API JSON
# [youtube] iYCutqWHVrI: Downloading mweb player API JSON
# [youtube] iYCutqWHVrI: Downloading player 78fcc867
# [youtube] iYCutqWHVrI: Downloading m3u8 information
# [info] iYCutqWHVrI: Downloading 1 format(s): 140
# [download] Destination: ./AI Project Test 1.m4a
# [download] 100% of  167.55KiB in 00:00:00 at 627.89KiB/s
# [FixupM4a] Correcting container of "./AI Project Test 1.m4a"
# [ExtractAudio] Not converting audio ./AI Project Test 1.m4a; file is already in target format m4a
# Transcribing part 1!
# Deleted: ./AI Project Test 1.m4a
# pd: Recommend an action movie released between 2015 and 2017 with a rating of 7.0 or higher.
# (between 2015 and 2017, 7.0)
# ent label: DATE
# ent label: CARDINAL
# token: Recommend
# token: an
# token: action
# token: movie
# token: released
# token: between
# token: 2015
# token: and
# token: 2017
# token: with
# token: a
# token: rating
# token: of
# token: 7.0
# token: or
# token: higher
# token: .
# Genre: 28, Start Year: 2015, End Year: 2017, Min Rating: 7.0, Min Runtime: None, Max Runtime: None
# {'api_key': '7606a082a3cb4ebef8db46609a0994e0', 'language': 'en-US', 'sort_by': 'popularity.desc', 'include_adult': 'false', 'include_video': 'false', 'with_genres': 28, 'primary_release_date.gte': '2015-01-01', 'primary_release_date.lte': '2017-12-31', 'vote_average.gte': 7.0, 'page': 1}
# [{'adult': False, 'backdrop_path': '/en971MEXui9diirXlogOrPKmsEn.jpg', 'genre_ids': [28, 12, 35], 'id': 293660, 'original_language': 'en', 'original_title': 'Deadpool', 'overview': 'The origin story of former Special Forces operative turned mercenary Wade Wilson, who, after being subjected to a rogue experiment that leaves him with accelerated healing powers, adopts the alter ego Deadpool. Armed with his new abilities and a dark, twisted sense of humor, Deadpool hunts down the man who nearly destroyed his life.', 'popularity': 136.213, 'poster_path': '/3E53WEZJqP6aM84D8CckXx4pIHw.jpg', 'release_date': '2016-02-09', 'title': 'Deadpool', 'video': False, 'vote_average': 7.623, 'vote_count': 30893}, {'adult': False, 'backdrop_path': '/fn4n6uOYcB6Uh89nbNPoU2w80RV.jpg', 'genre_ids': [28, 12, 878, 18], 'id': 315635, 'original_language': 'en', 'original_title': 'Spider-Man: Homecoming', 'overview': 'Following the events of Captain America: Civil War, Peter Parker, with the help of his mentor Tony Stark, tries to balance his life as an ordinary high school student in Queens, New York City, with fighting crime as his superhero alter ego Spider-Man as a new threat, the Vulture, emerges.', 'popularity': 121.383, 'poster_path': '/c24sv2weTHPsmDa7jEMN0m2P3RT.jpg', 'release_date': '2017-07-05', 'title': 'Spider-Man: Homecoming', 'video': False, 'vote_average': 7.3, 'vote_count': 21651}, {'adult': False, 'backdrop_path': '/kaIfm5ryEOwYg8mLbq8HkPuM1Fo.jpg', 'genre_ids': [28, 12, 878], 'id': 284053, 'original_language': 'en', 'original_title': 'Thor: Ragnarok', 'overview': 'Thor is imprisoned on the other side of the universe and finds himself in a race against time to get back to Asgard to stop Ragnarok, the destruction of his home-world and the end of Asgardian civilization, at the hands of a powerful new threat, the ruthless Hela.', 'popularity': 112.605, 'poster_path': '/rzRwTcFvttcN1ZpX2xv4j3tSdJu.jpg', 'release_date': '2017-10-02', 'title': 'Thor: Ragnarok', 'video': False, 'vote_average': 7.6, 'vote_count': 20634}, {'adult': False, 'backdrop_path': '/brnfCYyz8EMbBrHgmh8sCwBi5i1.jpg', 'genre_ids': [27, 53, 28], 'id': 396535, 'original_language': 'ko', 'original_title': '부산행', 'overview': 'When a zombie virus pushes Korea into a state of emergency, those trapped on an express train to Busan must fight for their own survival.', 'popularity': 109.882, 'poster_path': '/vNVFt6dtcqnI7hqa6LFBUibuFiw.jpg', 'release_date': '2016-07-20', 'title': 'Train to Busan', 'video': False, 'vote_average': 7.754, 'vote_count': 7370}, {'adult': False, 'backdrop_path': '/gqrnQA6Xppdl8vIb2eJc58VC1tW.jpg', 'genre_ids': [28, 12, 878], 'id': 76341, 'original_language': 'en', 'original_title': 'Mad Max: Fury Road', 'overview': 'An apocalyptic story set in the furthest reaches of our planet, in a stark desert landscape where humanity is broken, and most everyone is crazed fighting for the necessities of life. Within this world exist two rebels on the run who just might be able to restore order.', 'popularity': 104.8, 'poster_path': '/hA2ple9q4qnwxp3hKVNhroipsir.jpg', 'release_date': '2015-05-13', 'title': 'Mad Max: Fury Road', 'video': False, 'vote_average': 7.615, 'vote_count': 22495}, {'adult': False, 'backdrop_path': '/xnqust9Li4oxfhXD5kcPi3UC8i4.jpg', 'genre_ids': [28, 12, 878], 'id': 99861, 'original_language': 'en', 'original_title': 'Avengers: Age of Ultron', 'overview': 'When Tony Stark tries to jumpstart a dormant peacekeeping program, things go awry and Earth’s Mightiest Heroes are put to the ultimate test as the fate of the planet hangs in the balance. As the villainous Ultron emerges, it is up to The Avengers to stop him from enacting his terrible plans, and soon uneasy alliances and unexpected action pave the way for an epic and unique global adventure.', 'popularity': 102.56, 'poster_path': '/4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg', 'release_date': '2015-04-22', 'title': 'Avengers: Age of Ultron', 'video': False, 'vote_average': 7.274, 'vote_count': 22870}, {' ...
# Deadpool (2016) - Rating: 7.623, Runtime: 108 min
